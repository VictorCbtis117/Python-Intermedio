# %% [markdown]
# # Primer Cuaderno

# %%
print("Hola mundo")

# %% [markdown]
# ## Entrada

# %%
nombre=input("Nombre")
print(nombre)

# %% [markdown]
# # Pandas

# %% [markdown]
# ## CSV

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("Perfil de estudiante.csv")
print(df.to_string() )

# %% [markdown]
# ## JSON

# %%
import numpy as np
import pandas as pd
df = pd.read_json("dataset.json")
print(df.to_string() )

# %% [markdown]
# ## Ejemplos

# %%
import pandas as pd
data = {
    'Nombre': ['Juan', 'María', 'Pedro', 'Ana', 'Luis'],
    'Edad': [25, 32, None, 42, 28],
    'Fecha': ['31/01/2020', '31/01/2020', None, '31/01/2020', '01/31/2020'],
    'Género': ['M', 'F', None, 'F', 'M'],
    'Ciudad': ['Madrid', None, 'Madrid', 'Valencia', 'Barcelona'],
    'Altura': [175, 163, 180, 158, 170],
    'Peso': [70, None, 80, 60, 75],
    'Ingresos': [50000, 60000, 40000, None, 55000]}

df=pd.DataFrame(data)

df_sin_vacios=df.dropna()
print(df_sin_vacios.to_string())
#muestra sin vacios

#dfna=df.dropna(inplace=True)
#print(dfna.to_string())

#los vacios se rellenan con la frase
df_relleno=df.fillna("Sin registro")
print(df_relleno.to_string())

media=df["Ingresos"].mean()
print(media)

df_media=df["Ingresos"].fillna(media)
print(df_media)

# %% [markdown]
# # Limpieza de datos

# %%
import pandas as pd
data = {
    'Nombre': ['Juan', 'María', 'Pedro', 'Ana', 'Luis'],
    'Edad': [25, 32, None, 42, 28],
    'Fecha': ['31/01/2020', '31/01/2020', None, '31/01/2020', '01/31/2020'],
    'Género': ['M', 'F', None, 'F', 'M'],
    'Ciudad': ['Madrid', None, 'Madrid', 'Valencia', 'Barcelona'],
    'Altura': [175, 163, 180, 158, 170],
    'Peso': [70, None, 80, 60, 75],
    'Ingresos': [50000, 60000, 40000, None, 55000]}

df= pd.DataFrame(data)

# %%
#df.info()
#mostrar informacion del dataframe

# %%
mediana_edad=df["Edad"].median()
df["Edad"].fillna(mediana_edad,inplace=True)

print (df.to_string())

# %% [markdown]
# # Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
#usar pyplot para usar as graficas

puntos_x= np.array([0,4,8,16,24])
puntos_y=np.array([6,36,12,48,24])

plt.plot(puntos_x,puntos_y,'o--k',ms=16,mec='r',linewidth='1')
#ms-marquer size
#mec -color del marcador
#linea personalizada o marcador
#puntos lineas verde

plt.title("Estadisticas")
plt.xlabel("Eje X")
plt.ylabel("Eje Vertical")
plt.show()
